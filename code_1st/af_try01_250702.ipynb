# %% [markdown]
# # AF推定

# %% [markdown]
# - 心拍数推定を元に、AF推定を試す

# %%
# 使ってないやつもありそうなので、最終的には整理する
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
import scipy.signal as signal
import scipy.stats as stats
import soundfile as sf
import joblib

from pathlib import Path
from Utils import resample_waveform, spike_removal, hpf, lpf, get_sound_vol, wavelet_denoising, rms_agc_2stages, compress_peak_power,sliding_window_peak_detection, peak_interval_estimation, peak_count_estimation, detect_peaks_with_FFT, peak_variation_estimation

# %% [markdown]
# ## データ読み込み

# %%
# データの読み込み
file_path = os.path.join('..','250624_af_dataset_all.xlsx')
wav_df = pd.read_excel(file_path)

# 抽出とインデックスリセット（必要に応じて指定）
# wav_df = wav_df[wav_df['exp_study'] == 1].reset_index(drop=True)
# wav_df = wav_df[wav_df['is_third_heart_sound'] != 1].reset_index(drop=True)
# wav_df = wav_df[wav_df['AF'] == 0].reset_index(drop=True)

# 列番号258～796を持つデータのみを抽出
# wav_df = wav_df[wav_df['number'].between(258, 796)].reset_index(drop=True)

# AFデータのWAVファイルが格納されているルートディレクトリのパス
wav_root = os.path.join('..', '..', 'wav_af')

# データ数を表示
print(f"データ数: {len(wav_df)}")
# Out:
# データ数: 2020

# %% [markdown]
# # process

# %%
### parameters ###
window_size_sec = 2 # １はNG
step_size_sec = 1
min_lag_bpm_normal = 120  # ピーク検出の最小bpm(normal)
min_lag_bpm_tachy = 220  # ピーク検出の最小bpm(tachy)
min_lag_coeff_normal = 1/(min_lag_bpm_normal/60)  # ピーク検出の最小時間(normal)
min_lag_coeff_tachy = 1/(min_lag_bpm_tachy/60)  # ピーク検出の最小時間(tachy)

fs = 1000 # 元のサンプリングレートを使う場合はsrを指定(通常1000Hz)
fc_hpf = 16.5  # HPFのカットオフ周波数
fc_lpf = 62  # LPFのカットオフ周波数
k_thr = 0.45  # ウェーブレット分解のしきい値
ma_window_size = 55  # 移動平均のウィンドウサイズ
comp_thr = 0.581  # コンプレッションのしきい値
comp_rat = 0.657  # コンプレッションの比率
prom_coeff_normal = 2.5  # ピーク検出のprominence係数(normal)
prom_coeff_tachy = 0.05  # ピーク検出のprominence係数(tachy)
height_qxx = 50  # ピーク検出のheight係数
height_coeff_normal = 1.5  # ピーク検出のheight係数(normal)
height_coeff_tachy = 0.5  # ピーク検出のheight係数(tachy)

### プロット設定 ###
plot_enable = False  # True:プロット表示, False:プロット非表示
FFT_plot_enable = False

### tachy判定モデルの読み込み ###
rf_model = joblib.load('randomforest_model_selected5_250630.pkl')
rf_imputer = joblib.load('randomforest_imputer_selected5_250630.pkl')

# 結果を格納するデータフレームを作成
all_results = []

""" for loop """
test_run = False  # テスト実行フラグ
# テスト実行時は指定範囲、本番実行時は全件処理
for i in range(0, 2) if test_run else range(len(wav_df)):
    file_name = wav_df['wav_name'][i]  # ファイル名を取得
    file_path = os.path.join(wav_root, file_name)  # wav_rootフォルダ内のファイルパスを指定
    data, sr = sf.read(file_path, dtype='int16')  # soundfileでwavファイルを読み込み

    # Filter
    data_res = resample_waveform(data, sr, fs)  # リサンプリング
    data_spike = spike_removal(data_res, window_size=5)  # スパイク除去
    data_hpf = hpf(data_spike, fs, fc_hpf)  # HPF
    data_lpf = lpf(data_hpf, fs, fc_lpf)  # LPF
    data = data_lpf
    time = np.arange(0, len(data))/fs

    # Sound Volume check
    ma_window = int(0.05 * fs +1)  # 移動平均するサンプル数（固定）
    vol_mean = get_sound_vol(data, fs, ma_window)
    wav_df.loc[i, 'sound_vol'] = vol_mean
    
    # 音量が小さい場合は以降の処理をスキップ
    if vol_mean <= 3000:
        print(f"Skipping {file_name} due to low volume (vol_mean={vol_mean:.1f})")
        continue

    ### Wavelet Denoising ###
    denoised_signal, coeffs_info = wavelet_denoising(data, wavelet='bior6.8', k_thr=k_thr, max_level=7)

    ### RMS-AGC 2-stages ###
    rms_env2_interp, rms_env2_ma = rms_agc_2stages(denoised_signal, fs,
                                  fade_sec=0.5,
                                  hop_size_sec=0.01,
                                  frame_size_sec=0.05,
                                  ma_window_size=ma_window_size,
                                  agc1_params=None,
                                  agc2_params=None)

    ### コンプレッション ###
    rms_env2_ma_comp = rms_env2_ma/(max(rms_env2_ma)+1e-8)
    rms_env2_ma_comp = compress_peak_power(rms_env2_ma_comp, threshold=comp_thr, ratio=comp_rat)

    ### 窓ごとピーク検出 ###
    peak_results = sliding_window_peak_detection(
        signal=rms_env2_ma_comp,
        fs=fs,
        window_size_sec=window_size_sec,
        step_size_sec=step_size_sec,
        min_lag_bpm_normal=min_lag_bpm_normal,
        min_lag_bpm_tachy=min_lag_bpm_tachy,
        prom_coeff_normal=prom_coeff_normal,
        prom_coeff_tachy=prom_coeff_tachy,
        height_qxx=height_qxx,
        height_coeff_normal=height_coeff_normal,
        height_coeff_tachy=height_coeff_tachy,
        plot=plot_enable
        )

    # 結果を取得
    avg_peak_count_normal = peak_results['avg_peak_count_normal']  # 平均ピーク間隔(normal)
    time_peaks_normal = peak_results['time_peaks_normal']  # ピークの時刻(normal)
    avg_peak_count_tachy = peak_results['avg_peak_count_tachy']  # 平均ピーク間隔(tachy)
    time_peaks_tachy = peak_results['time_peaks_tachy']  # ピークの時刻(tachy)


    ### ピークインターバル法で心拍数を推定 ###
    hr_interval_normal, hr_interval_tachy = peak_interval_estimation(
        avg_peak_count_normal,
        avg_peak_count_tachy,
        )

    ### ピークカウント法で心拍数を推定 ###
    hr_count_normal, hr_count_tachy = peak_count_estimation(
        time_peaks_normal,
        time_peaks_tachy,
        rms_env2_ma_comp,
        fs
        )

    ### FFTピーク検出と特徴量抽出（可視化も含む） ###
    save_path = os.path.join('figures', file_name.replace('.wav', '.jpeg'))
    features = detect_peaks_with_FFT(
        signal=rms_env2_interp,
        fs=fs,
        desired_sec=15,
        high_freq_thr=5.5,
        power_thr=0.3,
        prominence_coeff=0.6,
        height_threshold=0.01,
        plot=FFT_plot_enable,
        file_name=file_name,
        note_x=wav_df['note_x'][i],
        vol_mean=vol_mean,
        actual_hr=wav_df['heart_rate'][i],  # 実装時は削除
        # save_path=save_path # 指定するとグラフ保存
    )
    
    ### 特徴量を個別変数として取得 ###
    bpm_first_peak = features['bpm_first_peak']
    bpm_dominant_peak = features['bpm_dominant_peak']
    max_power_under_220 = features['max_power_under_220']
    high_freq_peaks = features['high_freq_peaks']
    bpm_spectrum_centroid = features['bpm_spectrum_centroid']
    
    # FFT特徴量辞書を作成（頻脈判定用）
    FFT_feature_dict = {
        'bpm_first_peak': bpm_first_peak,
        'bpm_dominant_peak': bpm_dominant_peak,
        'max_power_under_220': max_power_under_220,
        'high_freq_peaks': high_freq_peaks,
        'bpm_spectrum_centroid': bpm_spectrum_centroid,    }
    
    ### RandomForestによる頻脈判定 ###
    tachy_features_df = pd.DataFrame(FFT_feature_dict, index=[0])  # 特徴量をDataFrameに変換
    tachy_features_df_imputed = pd.DataFrame(rf_imputer.transform(tachy_features_df), columns=tachy_features_df.columns)  # 列名を保持したまま欠損値を補完
    tachy_flag = rf_model.predict(tachy_features_df_imputed).astype(int)  # 頻脈判定
    tachy_prob = rf_model.predict_proba(tachy_features_df_imputed)[:, 1]  # 頻脈判定確率

    ### FFT法の心拍数推定結果 ###
    # 心拍数上限を200とする。
    # normal
    hr_FFT_normal = bpm_first_peak
    if hr_FFT_normal > 200: 
        hr_FFT_normal = int(hr_FFT_normal/2)  # 200以上は2で割る
    else:
        hr_FFT_normal = int(hr_FFT_normal)
    
    # tachy
    hr_FFT_tachy = bpm_dominant_peak
    if hr_FFT_tachy > 200:  
        hr_FFT_tachy = int(hr_FFT_tachy/2)  # 200以上は2で割る
    else:
        hr_FFT_tachy = int(hr_FFT_tachy)

    ### 統合手法で心拍数を推定 ###
    hr_list_normal = [hr_interval_normal, hr_count_normal, hr_FFT_normal]  
    hr_list_tachy = [hr_interval_tachy, hr_count_tachy, hr_FFT_tachy]
    
    if tachy_flag == 0:
        hr_integrated = int(np.median(hr_list_normal))
    elif tachy_flag == 1:
        hr_integrated = hr_FFT_tachy
    else:
        hr_integrated = np.nan

    ### 各手法の結果を辞書として保存 ###
    hr = wav_df['heart_rate'][i]

    ### ピーク間隔のばらつきを計算 ###
    # 確認のため、計算に使用するピーク時刻と間隔を出力
    variation, time_peaks_normal_unique, intervals_normal, \
    time_peaks_tachy_unique, intervals_tachy = \
    peak_variation_estimation(
        time_peaks_normal,
        time_peaks_tachy
    )

    ### 結果を辞書としてまとめる ###
    results_data = {
        'number': i,  # 通し番号
        'wav_name': file_name,
        'note_x': wav_df['note_x'][i],
        'is_third_heart_sound': wav_df['is_third_heart_sound'][i],
        'sound_vol': vol_mean,
        'heart_rate': hr,
        'hr_interval_normal': hr_interval_normal,
        'hr_interval_tachy': hr_interval_tachy,
        'hr_count_normal': hr_count_normal,
        'hr_count_tachy': hr_count_tachy,
        'FFT_first': bpm_first_peak,
        'FFT_dominant': bpm_dominant_peak,
        'hr_FFT_normal': hr_FFT_normal,
        'hr_FFT_tachy': hr_FFT_tachy,
        'hr_integrated': hr_integrated,
        'tachy_flag': tachy_flag,
        'tachy_prob': tachy_prob,
        'AF': wav_df['AF'][i],
        'peak_std_normal': variation['normal']['std'],
        'peak_std_tachy': variation['tachy']['std'],
        'peak_mad_normal': variation['normal']['mad'],
        'peak_mad_tachy': variation['tachy']['mad'],
        'peak_var_normal': variation['normal']['var'],
        'peak_var_tachy': variation['tachy']['var'],
        'peak_rmssd_normal': variation['normal']['rmssd'],
        'peak_rmssd_tachy': variation['tachy']['rmssd'],
        'peak_nn50_normal': variation['normal']['nn50'],
        'peak_nn50_tachy': variation['tachy']['nn50'],
        'peak_nn20_normal': variation['normal']['nn20'],
        'peak_nn20_tachy': variation['tachy']['nn20'],
        'peak_pnn50_normal': variation['normal']['pnn50'],
        'peak_pnn50_tachy': variation['tachy']['pnn50'],
        'peak_pnn20_normal': variation['normal']['pnn20'],
        'peak_pnn20_tachy': variation['tachy']['pnn20'],
        }
    all_results.append(results_data)

    print(f"ファイル：{file_name} 処理完了, 推定：{hr_integrated}, 頻脈判定：{tachy_flag}, NN分散：{variation['normal']['var']:0.3f}, {variation['tachy']['var']:0.3f}")
    print(f"note_x：{wav_df['note_x'][i]}")

all_results_df = pd.DataFrame(all_results)

### データフレームを保存 ###
# resultフォルダが無い場合は作成
if not os.path.exists('result'):
    os.makedirs('result')
all_results_df.to_csv('result/af_test_250704.csv', encoding='utf-8-sig', index=False)
all_results_df.to_pickle('result/af_test_250704.pkl')
print("結果を保存しました。")
# Out:
# ファイル：3002_20240114070258_163.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.032, 0.040
# note_x：正常
# ファイル：1003_20240126081339_365.wav 処理完了, 推定：96, 頻脈判定：[0], NN分散：0.001, 0.020
# note_x：正常
# ファイル：1003_20240126180226_375.wav 処理完了, 推定：94, 頻脈判定：[0], NN分散：0.010, 0.004
# note_x：正常
# ファイル：1004_20240202132845_632.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.065, 0.022
# note_x：正常
# ファイル：3005_20240202143120_634.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.024, 0.008
# note_x：正常
# ファイル：1004_20240206190416_832.wav 処理完了, 推定：78, 頻脈判定：[0], NN分散：0.003, 0.026
# note_x：正常
# ファイル：1004_20240208083659_892.wav 処理完了, 推定：73, 頻脈判定：[0], NN分散：0.086, 0.012
# note_x：正常
# ファイル：4002_20240209174433_964.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.032, 0.086
# note_x：正常
# Skipping 4002_20240210184148_1024.wav due to low volume (vol_mean=2984.0)
# ファイル：1005_20240212073036_1090.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.070, 0.049
# note_x：とてもきれいに撮れている。低調な収縮期雑音あり。S3なし。
# ファイル：3009_20240228134341_1967.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.089, 0.043
# note_x：正常
# ファイル：3006_20240229070350_1990.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.080, 0.030
# note_x：正常
# ファイル：1005_20240301114632_2134.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.064, 0.061
# note_x：収縮期雑音あり。S3なし。
# ファイル：3009_20240301115220_2135.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.000, 0.037
# note_x：正常
# ファイル：1008_20240326161815_4752.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.025, 0.040
# note_x：特になし
# ファイル：1007_20240330070932_5164.wav 処理完了, 推定：78, 頻脈判定：[0], NN分散：0.000, 0.009
# note_x：正常
# ファイル：3008_20240330105538_5196.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.036, 0.026
# note_x：正常
# ファイル：4003_20240405180100_5969.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.000, 0.035
# note_x：正常
# ファイル：1008_20240408065803_6259.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.001, 0.062
# note_x：バッチリ！
# ファイル：3008_20240416141938_7325.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.051, 0.025
# note_x：正常
# ファイル：1010_20240420065827_7695.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.000, 0.022
# note_x：正常
# ファイル：3010_20240422080108_7981.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.027, 0.020
# note_x：正常
# ファイル：3002_20240427180110_8755.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.000, 0.037
# note_x：正常
# ファイル：3011_20240429082032_8959.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.015, 0.045
# note_x：正常
# ファイル：3011_20240430180401_9196.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.026, 0.048
# note_x：正常
# ファイル：3012_20240506193947_10113.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.028, 0.046
# note_x：正常
# ファイル：1007_20240507110925_10162.wav 処理完了, 推定：73, 頻脈判定：[0], NN分散：0.048, 0.036
# note_x：正常
# ファイル：3012_20240508123258_10315.wav 処理完了, 推定：52, 頻脈判定：[0], NN分散：0.080, 0.070
# note_x：やや徐脈
# ファイル：4003_20240511080044_10705.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.000, 0.013
# note_x：正常
# ファイル：3007_20240518074239_11635.wav 処理完了, 推定：56, 頻脈判定：[0], NN分散：0.118, 0.064
# note_x：正常
# ファイル：1009_20240518091242_11666.wav 処理完了, 推定：56, 頻脈判定：[0], NN分散：0.089, 0.056
# note_x：正常
# ファイル：1010_20240607192212_14575.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.058, 0.005
# note_x：正常
# ファイル：4011_20240611075123_15040.wav 処理完了, 推定：69, 頻脈判定：[0], NN分散：0.069, 0.011
# note_x：正常
# ファイル：3006_20240615071732_15586.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.128, 0.026
# note_x：正常
# ファイル：5001_20240617133250_15992.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.083, 0.022
# note_x：正常
# ファイル：1012_20240620180139_16509.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.000, 0.004
# note_x：正常
# ファイル：3005_20240702072223_18302.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.019, 0.015
# note_x：正常
# ファイル：5002_20240703150437_18570.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.061, 0.056
# note_x：正常
# ファイル：3010_20240711071818_20006.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.001, 0.043
# note_x：正常
# ファイル：5001_20240711075716_20018.wav 処理完了, 推定：63, 頻脈判定：[0], NN分散：0.098, 0.035
# note_x：正常
# ファイル：1008_20240711103537_20042.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.064, 0.036
# note_x：正常だが、脈早め。
# Skipping 4016_20240711183342_20149.wav due to low volume (vol_mean=2149.0)
# ファイル：1012_20240723080039_22119.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.004, 0.019
# note_x：正常
# ファイル：1011_20240723090248_22135.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.045, 0.065
# note_x：正常
# ファイル：2003_20240730164037_23404.wav 処理完了, 推定：86, 頻脈判定：[0], NN分散：0.000, 0.020
# note_x：正常
# ファイル：3007_20240730173546_23411.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.000, 0.059
# note_x：正常
# ファイル：5002_20240801173827_23728.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.032, 0.033
# note_x：正常
# ファイル：1013_20240802135159_23867.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.000, 0.030
# note_x：正常
# ファイル：4015_20240803081620_23972.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.073, 0.067
# note_x：正常
# ファイル：1009_20240807102159_24544.wav 処理完了, 推定：52, 頻脈判定：[0], NN分散：0.108, 0.077
# note_x：正常
# ファイル：2003_20240808080234_24670.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.046, 0.003
# note_x：正常
# ファイル：4011_20240910134647_29257.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.038, 0.019
# note_x：正常
# ファイル：4016_20240923120757_31000.wav 処理完了, 推定：87, 頻脈判定：[0], NN分散：0.004, 0.003
# note_x：正常
# ファイル：1011_20241011085753_32933.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.052, 0.060
# note_x：正常
# ファイル：4015_20241020180219_34000.wav 処理完了, 推定：71, 頻脈判定：[0], NN分散：0.049, 0.039
# note_x：正常
# ファイル：1007_20241029184952_34880.wav 処理完了, 推定：99, 頻脈判定：[0], NN分散：0.011, 0.033
# note_x：正常
# ファイル：1007_20241029185125_34881.wav 処理完了, 推定：96, 頻脈判定：[0], NN分散：0.025, 0.041
# note_x：正常
# Skipping 4018_20241215181125_38302.wav due to low volume (vol_mean=2059.0)
# ファイル：4018_20241217180117_38423.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.000, 0.040
# note_x：正常
# ファイル：4017_20250109180139_39345.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.027, 0.029
# note_x：正常
# ファイル：1013_20250204093117_40010.wav 処理完了, 推定：108, 頻脈判定：[0], NN分散：0.000, 0.006
# note_x：少し脈早めだが正常
# ファイル：3002_20240112155034_143.wav 処理完了, 推定：91, 頻脈判定：[0], NN分散：0.000, 0.028
# note_x：脈早いが正常
# ファイル：3002_20240112185445_147.wav 処理完了, 推定：89, 頻脈判定：[0], NN分散：0.011, 0.028
# note_x：脈早いが正常
# Skipping 3002_20240113083623_151.wav due to low volume (vol_mean=2991.0)
# ファイル：3002_20240113133059_154.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.024, 0.027
# note_x：脈早いが正常
# Skipping 3002_20240113190155_158.wav due to low volume (vol_mean=2624.0)
# ファイル：1003_20240209182801_972.wav 処理完了, 推定：98, 頻脈判定：[0], NN分散：0.000, 0.001
# note_x：1-4秒あたりにⅢ音らしき音を僅かに認めるが、持続していないためⅢ音なしとする。
# ファイル：1003_20240210084310_984.wav 処理完了, 推定：101, 頻脈判定：[0], NN分散：0.000, 0.022
# note_x：典型的なⅢ音です。すべて。
# ファイル：1003_20240210084411_985.wav 処理完了, 推定：99, 頻脈判定：[0], NN分散：0.000, 0.026
# note_x：全部Ⅲ音あり
# ファイル：1003_20240210130708_1006.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.008, 0.001
# note_x：半分は2音の分裂のように聞こえるが、おそらくⅢ音
# ファイル：1003_20240210180919_1013.wav 処理完了, 推定：96, 頻脈判定：[0], NN分散：0.000, 0.003
# note_x：頻脈だけどⅢ音なし
# ファイル：1003_20240211091326_1037.wav 処理完了, 推定：102, 頻脈判定：[0], NN分散：0.000, 0.028
# note_x：全部Ⅲ音あり
# ファイル：1003_20240211091427_1038.wav 処理完了, 推定：101, 頻脈判定：[0], NN分散：0.000, 0.023
# note_x：２音の分裂のように聞こえるが、Ⅲ音と思われる。9-11秒以外、全てⅢ音なっている。
# ファイル：1003_20240211204608_1085.wav 処理完了, 推定：104, 頻脈判定：[0], NN分散：0.014, 0.025
# note_x：正常だけど頻脈。110 bpmくらいありそう
# ファイル：1007_20240212070404_1088.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.040, 0.020
# note_x：nan
# ファイル：1007_20240216182733_1375.wav 処理完了, 推定：97, 頻脈判定：[0], NN分散：0.000, 0.017
# note_x：nan
# ファイル：1007_20240217070416_1379.wav 処理完了, 推定：99, 頻脈判定：[0], NN分散：0.016, 0.021
# note_x：nan
# ファイル：1007_20240305194056_2546.wav 処理完了, 推定：100, 頻脈判定：[0], NN分散：0.026, 0.024
# note_x：頻脈だがⅢ音なし
# ファイル：1007_20240308183049_2876.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.062, 0.028
# note_x：nan
# ファイル：1007_20240311080057_3083.wav 処理完了, 推定：96, 頻脈判定：[0], NN分散：0.045, 0.006
# note_x：nan
# ファイル：1004_20240313085750_3299.wav 処理完了, 推定：184, 頻脈判定：[1], NN分散：0.041, 0.000
# note_x：HR 160 bpmくらいあるためⅢ音があるか評価不能。ただし、こんな頻脈自体が異常であるため、症状はありそう。
# ファイル：1004_20240313122006_3307.wav 処理完了, 推定：180, 頻脈判定：[1], NN分散：0.080, 0.000
# note_x：HR 160 くらいの頻脈でⅢ音があるか評価不能。ただし、この頻脈自体が異常なので、呼び出してもいいのでは。
# ファイル：1004_20240313190356_3347.wav 処理完了, 推定：180, 頻脈判定：[1], NN分散：0.036, 0.000
# note_x：かなりの頻脈。Ⅲ音はないがこんな頻脈自体が異常。
# ファイル：1004_20240314090630_3373.wav 処理完了, 推定：180, 頻脈判定：[1], NN分散：0.245, 0.027
# note_x：HR 150 くらいの頻脈。Ⅲ音はなさそう。ただし、この頻脈自体が異常なので、呼び出してもいいのでは。
# ファイル：1004_20240314123358_3380.wav 処理完了, 推定：180, 頻脈判定：[1], NN分散：0.132, 0.045
# note_x：HR 150 くらいの頻脈。Ⅲ音はなさそう。ただし、この頻脈自体が異常なので、呼び出してもいいのでは。
# ファイル：1004_20240314123452_3381.wav 処理完了, 推定：180, 頻脈判定：[1], NN分散：0.035, 0.008
# note_x：HR 150 くらいの頻脈。Ⅲ音はなさそう。ただし、この頻脈自体が異常なので、呼び出してもいいのでは。
# ファイル：1004_20240314123541_3382.wav 処理完了, 推定：180, 頻脈判定：[1], NN分散：0.026, 0.006
# note_x：HR 150 くらいの頻脈。Ⅲ音はなさそう。ただし、この頻脈自体が異常なので、呼び出してもいいのでは。
# ファイル：1004_20240314123630_3384.wav 処理完了, 推定：180, 頻脈判定：[1], NN分散：0.058, 0.003
# note_x：HR 140 くらいの頻脈。Ⅲ音はなさそう。ただし、この頻脈自体が異常なので、呼び出してもいいのでは。
# ファイル：1004_20240314123718_3385.wav 処理完了, 推定：180, 頻脈判定：[1], NN分散：0.025, 0.000
# note_x：HR 140 くらいの頻脈。Ⅲ音はなさそう。ただし、この頻脈自体が異常なので、呼び出してもいいのでは。
# ファイル：3006_20240416082336_7262.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.057, 0.015
# note_x：少し脈早め
# ファイル：3006_20240423072423_8103.wav 処理完了, 推定：95, 頻脈判定：[0], NN分散：0.004, 0.033
# note_x：nan
# ファイル：4011_20240423125919_8154.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.042, 0.004
# note_x：nan
# ファイル：3006_20240423134340_8173.wav 処理完了, 推定：90, 頻脈判定：[0], NN分散：0.043, 0.038
# note_x：nan
# ファイル：3006_20240424072101_8239.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.050, 0.020
# note_x：nan
# ファイル：3006_20240424114925_8275.wav 処理完了, 推定：86, 頻脈判定：[0], NN分散：0.015, 0.003
# note_x：nan
# ファイル：3011_20240426084200_8546.wav 処理完了, 推定：100, 頻脈判定：[0], NN分散：0.000, 0.022
# note_x：nan
# ファイル：3006_20240429071423_8920.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.028, 0.016
# note_x：nan
# ファイル：3011_20240429124355_8986.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.025, 0.035
# note_x：nan
# ファイル：3006_20240430120921_9116.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.092, 0.026
# note_x：nan
# ファイル：4011_20240501124127_9285.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.067, 0.009
# note_x：nan
# ファイル：3011_20240501134951_9313.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.077, 0.020
# note_x：nan
# ファイル：3006_20240505120538_9855.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.035, 0.019
# note_x：nan
# ファイル：3006_20240513112752_10997.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.074, 0.019
# note_x：nan
# ファイル：3011_20240513130731_11033.wav 処理完了, 推定：95, 頻脈判定：[0], NN分散：0.011, 0.026
# note_x：nan
# ファイル：3011_20240514175628_11167.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.055, 0.039
# note_x：nan
# Skipping 1010_20240516190237_11456.wav due to low volume (vol_mean=2564.0)
# ファイル：3006_20240526161008_12897.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.039, 0.006
# note_x：nan
# ファイル：3006_20240527132457_13035.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.056, 0.010
# note_x：nan
# ファイル：1012_20240625191316_17329.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.062, 0.016
# note_x：nan
# ファイル：4013_20240628132634_17748.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.060, 0.005
# note_x：nan
# ファイル：2003_20240730131415_23372.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.000, 0.030
# note_x：Ⅲ音ないが頻脈
# ファイル：2003_20240802073122_23787.wav 処理完了, 推定：86, 頻脈判定：[0], NN分散：0.167, 0.009
# note_x：正常だが頻脈
# ファイル：1010_20240802104416_23821.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.021, 0.010
# note_x：頻脈になっている
# ファイル：1013_20240903083346_28123.wav 処理完了, 推定：104, 頻脈判定：[0], NN分散：0.000, 0.024
# note_x：脈早め
# Skipping 1013_20240903133824_28167.wav due to low volume (vol_mean=1963.0)
# ファイル：1013_20240903210003_28204.wav 処理完了, 推定：96, 頻脈判定：[0], NN分散：0.000, 0.000
# note_x：脈早め
# ファイル：1013_20240904072910_28227.wav 処理完了, 推定：99, 頻脈判定：[0], NN分散：0.000, 0.008
# note_x：脈早め
# ファイル：1013_20240904133752_28299.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.018, 0.008
# note_x：脈早め
# ファイル：1013_20240904213038_28348.wav 処理完了, 推定：99, 頻脈判定：[0], NN分散：0.000, 0.022
# note_x：脈早め
# ファイル：1013_20240905075307_28366.wav 処理完了, 推定：108, 頻脈判定：[0], NN分散：0.000, 0.016
# note_x：脈早め
# Skipping 1013_20240905133358_28444.wav due to low volume (vol_mean=2115.0)
# ファイル：1013_20240906131435_28608.wav 処理完了, 推定：100, 頻脈判定：[0], NN分散：0.001, 0.020
# note_x：脈早め
# ファイル：1013_20240906203645_28678.wav 処理完了, 推定：100, 頻脈判定：[0], NN分散：0.000, 0.012
# note_x：脈早め
# ファイル：5002_20241009071813_32682.wav 処理完了, 推定：162, 頻脈判定：[1], NN分散：0.098, 0.020
# note_x：VTなのか？
# ファイル：1012_20241023080913_34233.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.023, 0.031
# note_x：nan
# ファイル：2003_20241023113933_34251.wav 処理完了, 推定：95, 頻脈判定：[0], NN分散：0.009, 0.025
# note_x：nan
# ファイル：1012_20241026084056_34525.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.007, 0.021
# note_x：nan
# ファイル：1012_20241028083033_34722.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.057, 0.028
# note_x：nan
# Skipping 4016_20241207160513_37858.wav due to low volume (vol_mean=1722.0)
# Skipping 4016_20250104113953_39142.wav due to low volume (vol_mean=1890.0)
# ファイル：4016_20250104163428_39153.wav 処理完了, 推定：91, 頻脈判定：[0], NN分散：0.023, 0.018
# note_x：ちょっと脈早い
# ファイル：1003_20240209091039_939.wav 処理完了, 推定：96, 頻脈判定：[0], NN分散：0.000, 0.025
# note_x：ほぼ全心拍においてⅢ音もしくはⅢ音＋Ⅳ音をセットに認める。いわゆるギャロップ。これは絶対にノイズにしちゃダメな症例。
# ファイル：1012_20241210141653_38030.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.061, 0.047
# note_x：ほぼ全てにⅢ音あり。
# ファイル：5001_20241014122339_33306.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.074, 0.018
# note_x：しっかりとⅢ音あり
# ファイル：1007_20240426164458_8605.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.031, 0.021
# note_x：半分くらいにⅢ音あり
# ファイル：5001_20241004140832_32260.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.124, 0.028
# note_x：Ⅲ音あり
# ファイル：1007_20240412120429_6813.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.053, 0.016
# note_x：ほぼ全体にⅢ音あり
# ファイル：2003_20240731205808_23588.wav 処理完了, 推定：97, 頻脈判定：[0], NN分散：0.001, 0.018
# note_x：早くてわかりづらいがⅢ音あり。そして頻脈
# ファイル：5001_20241202075846_37595.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.183, 0.024
# note_x：かろうじてⅢ音が聞こえる
# ファイル：5001_20241126174104_37268.wav 処理完了, 推定：65, 頻脈判定：[0], NN分散：0.069, 0.035
# note_x：Ⅲ音あり
# ファイル：1007_20240430164306_9168.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.049, 0.045
# note_x：ほぼ全部にⅢ音あり
# ファイル：1007_20240413113540_6940.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.030, 0.010
# note_x：ほぼ全体にⅢ音なってます
# ファイル：1012_20241205172927_37767.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.020, 0.012
# note_x：PACの後からⅢ音がはっきりと聞こえる。
# ファイル：3008_20240405093122_5907.wav 処理完了, 推定：44, 頻脈判定：[0], NN分散：0.128, 0.124
# note_x：ほぼ全てにⅢ音あり
# ファイル：1012_20240621181852_16670.wav 処理完了, 推定：52, 頻脈判定：[0], NN分散：0.062, 0.029
# note_x：後半はⅢ音がはっきりと聞こえる。
# ファイル：5001_20241023090441_34237.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.054, 0.014
# note_x：Ⅲ音あり
# ファイル：1012_20241217180438_38424.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.036, 0.012
# note_x：AFibかPACか判別はできないが、Ⅲ音あり
# ファイル：1012_20241214085630_38227.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.174, 0.009
# note_x：ほぼ全てにⅢ音あり。
# ファイル：5001_20241016080002_33501.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.271, 0.053
# note_x：5−10秒でⅢ音あり
# ファイル：1007_20240317124030_3721.wav 処理完了, 推定：164, 頻脈判定：[1], NN分散：0.064, 0.006
# note_x：ほぼ全体にⅢ音あり
# ファイル：1007_20240413171819_6979.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.086, 0.012
# note_x：ほぼ全体にⅢ音あり。綺麗な音で教科書に載せられるくらい。
# Skipping 1008_20240919063022_30394.wav due to low volume (vol_mean=1800.0)
# ファイル：1008_20240524062143_12463.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.062, 0.030
# note_x：かなりシグナルが弱いがギリギリ正常
# ファイル：4002_20240901080504_27886.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.051, 0.046
# note_x：シグナル少し弱いがぎりぎり正常
# ファイル：1003_20240202130353_629.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.000, 0.004
# note_x：ノイズが中盤から入るため判定には向かないが、ギリギリ使えるレベル。ノイズがⅢ音らしく聞こえる部分があるが、4割ルールは満たさないため正常。
# ファイル：5001_20240628073049_17666.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.133, 0.024
# note_x：シグナル弱いが、ギリギリ解析可能。正常。
# Skipping 4002_20240211180830_1081.wav due to low volume (vol_mean=2531.0)
# ファイル：1003_20240131181533_487.wav 処理完了, 推定：96, 頻脈判定：[0], NN分散：0.003, 0.029
# note_x：少しノイズあるが、ギリギリセーフ
# ファイル：1003_20240215150647_1310.wav 処理完了, 推定：104, 頻脈判定：[0], NN分散：0.038, 0.002
# note_x：基本的には正常だが、終盤はノイズが多い。ギリギリ合格。
# Skipping 1008_20240818070205_26105.wav due to low volume (vol_mean=2623.0)
# Skipping 5001_20240628072853_17665.wav due to low volume (vol_mean=2389.0)
# ファイル：1008_20240815180108_25795.wav 処理完了, 推定：63, 頻脈判定：[0], NN分散：0.001, 0.069
# note_x：正常だが、ギリギリのS/N
# ファイル：4002_20240212185151_1152.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.049, 0.057
# note_x：何か音楽なっている。ギリギリ正常
# ファイル：1003_20240209132609_956.wav 処理完了, 推定：95, 頻脈判定：[0], NN分散：0.000, 0.019
# note_x：音小さめだが、ギリギリ判定可能。正常。
# ファイル：5001_20240626062606_17349.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.030, 0.012
# note_x：ノイズ多めだが、ギリギリ判定可能。正常
# ファイル：4002_20240218132805_1454.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.069, 0.099
# note_x：不整だがⅢ音なし。背景ノイズもギリギリOK
# ファイル：5001_20240628124516_17718.wav 処理完了, 推定：57, 頻脈判定：[0], NN分散：0.030, 0.074
# note_x：ノイズ多めだが、ギリギリ解析可能。正常。
# Skipping 4002_20240228130148_1958.wav due to low volume (vol_mean=1789.0)
# ファイル：1007_20240305122626_2496.wav 処理完了, 推定：55, 頻脈判定：[0], NN分散：0.091, 0.043
# note_x：ギリギリ診断できるレベル。正常。
# ファイル：4002_20240224193434_1719.wav 処理完了, 推定：67, 頻脈判定：[0], NN分散：0.053, 0.099
# note_x：かなり背景ノイズが多いが、ぎりぎり正常とする
# ファイル：1008_20240823130441_26803.wav 処理完了, 推定：65, 頻脈判定：[0], NN分散：0.077, 0.052
# note_x：正常だが、ノイズも多い。ギリギリOK
# ファイル：1008_20240621120746_16609.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.022, 0.020
# note_x：正常
# Skipping 1008_20240512180326_10929.wav due to low volume (vol_mean=2831.0)
# ファイル：1008_20240502073450_9381.wav 処理完了, 推定：65, 頻脈判定：[0], NN分散：0.069, 0.041
# note_x：正常
# ファイル：1008_20240526130244_12873.wav 処理完了, 推定：58, 頻脈判定：[0], NN分散：0.000, 0.047
# note_x：正常
# ファイル：1008_20240724071625_22267.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.034, 0.039
# note_x：正常
# ファイル：4002_20240225184934_1796.wav 処理完了, 推定：48, 頻脈判定：[0], NN分散：0.051, 0.126
# note_x：正常
# Skipping 4016_20250105164057_39187.wav due to low volume (vol_mean=1815.0)
# ファイル：1008_20240625174945_17313.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.057, 0.029
# note_x：正常
# ファイル：4007_20240910080432_29193.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.046, 0.039
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：5001_20240713073148_20378.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.052, 0.032
# note_x：正常
# ファイル：1008_20240506122952_10020.wav 処理完了, 推定：73, 頻脈判定：[0], NN分散：0.075, 0.034
# note_x：正常
# ファイル：4007_20240910073835_29180.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.074, 0.032
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4002_20240902131040_28039.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.022, 0.058
# note_x：正常
# ファイル：1008_20240608070347_14592.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.028, 0.019
# note_x：正常
# ファイル：3006_20240228123941_1952.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.000, 0.010
# note_x：正常
# ファイル：1005_20240204080330_695.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.121, 0.074
# note_x：低調な漸減性収縮期雑音あり。ASらしき音。それ以外は正常。
# ファイル：5001_20240727181439_22907.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.134, 0.041
# note_x：正常
# ファイル：1008_20240427180441_8763.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.002, 0.044
# note_x：正常
# ファイル：4002_20240229075654_2001.wav 処理完了, 推定：49, 頻脈判定：[0], NN分散：0.087, 0.066
# note_x：正常
# ファイル：3008_20240220150217_1527.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.000, 0.036
# note_x：7-8秒にⅢ音あり。全体としては少ないので正常とする
# ファイル：5001_20241025191304_34494.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.113, 0.019
# note_x：ノイズ多めだがぎりぎりⅢ音あり
# ファイル：5001_20241022152907_34176.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.101, 0.041
# note_x：ノイズ多めだがギリギリⅢ音ありと判定する。
# ファイル：5001_20241024135804_34358.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.121, 0.023
# note_x：ノイズ多めだがギリギリⅢ音あり
# ファイル：5001_20241113070638_36260.wav 処理完了, 推定：78, 頻脈判定：[0], NN分散：0.046, 0.023
# note_x：シグナルが弱いがギリギリⅢ音が聞こえる
# ファイル：5001_20241027075144_34611.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.326, 0.037
# note_x：ノイズ多めだが、ぎりぎりⅢ音あり
# ファイル：ZCH0006.wav 処理完了, 推定：140, 頻脈判定：[1], NN分散：0.083, 0.002
# note_x：nan
# ファイル：ZCH0017.wav 処理完了, 推定：136, 頻脈判定：[1], NN分散：0.057, 0.000
# note_x：nan
# ファイル：ZCH0020.wav 処理完了, 推定：118, 頻脈判定：[1], NN分散：0.029, 0.011
# note_x：nan
# ファイル：ZCH0023.wav 処理完了, 推定：109, 頻脈判定：[0], NN分散：0.025, 0.021
# note_x：nan
# ファイル：ZCH0024.wav 処理完了, 推定：85, 頻脈判定：[0], NN分散：0.080, 0.024
# note_x：nan
# ファイル：ZCH0025.wav 処理完了, 推定：128, 頻脈判定：[1], NN分散：0.076, 0.009
# note_x：nan
# ファイル：ZCH0028.wav 処理完了, 推定：103, 頻脈判定：[0], NN分散：0.010, 0.030
# note_x：徐々に下がっていく
# ファイル：ZCH0032.wav 処理完了, 推定：108, 頻脈判定：[0], NN分散：0.003, 0.018
# note_x：nan
# Skipping ZCH0033.wav due to low volume (vol_mean=2202.0)
# ファイル：ZCH0035.wav 処理完了, 推定：122, 頻脈判定：[1], NN分散：0.069, 0.005
# note_x：綺麗な音
# ファイル：ZCH0038.wav 処理完了, 推定：107, 頻脈判定：[0], NN分散：0.000, 0.018
# note_x：nan
# ファイル：ZCH0039.wav 処理完了, 推定：114, 頻脈判定：[1], NN分散：0.024, 0.021
# note_x：低音のノイズあり
# ファイル：ZCH0044.wav 処理完了, 推定：130, 頻脈判定：[1], NN分散：0.059, 0.006
# note_x：ノイズ、変動あり
# ファイル：ZCH0057.wav 処理完了, 推定：126, 頻脈判定：[1], NN分散：0.079, 0.013
# note_x：徐々に上がっていく
# ファイル：ZCH0062.wav 処理完了, 推定：134, 頻脈判定：[1], NN分散：0.115, 0.006
# note_x：nan
# ファイル：ZCH0070.wav 処理完了, 推定：108, 頻脈判定：[0], NN分散：0.009, 0.018
# note_x：nan
# ファイル：ZCH0074.wav 処理完了, 推定：130, 頻脈判定：[1], NN分散：0.134, 0.012
# note_x：徐々に下がる
# ファイル：ZCH0077.wav 処理完了, 推定：114, 頻脈判定：[1], NN分散：0.000, 0.005
# note_x：nan
# ファイル：ZCH0080.wav 処理完了, 推定：140, 頻脈判定：[1], NN分散：0.080, 0.002
# note_x：nan
# ファイル：ZCH0082.wav 処理完了, 推定：123, 頻脈判定：[1], NN分散：0.096, 0.015
# note_x：nan
# ファイル：ZCH0085.wav 処理完了, 推定：118, 頻脈判定：[1], NN分散：0.028, 0.012
# note_x：nan
# Skipping ZCH0092.wav due to low volume (vol_mean=2448.0)
# ファイル：ZCH0106.wav 処理完了, 推定：156, 頻脈判定：[1], NN分散：0.082, 0.000
# note_x：徐々に下がる
# ファイル：ZCH0109.wav 処理完了, 推定：136, 頻脈判定：[1], NN分散：0.084, 0.029
# note_x：少し変動
# ファイル：ZCH0113.wav 処理完了, 推定：134, 頻脈判定：[1], NN分散：0.089, 0.002
# note_x：nan
# ファイル：ZCH0119.wav 処理完了, 推定：138, 頻脈判定：[1], NN分散：0.078, 0.000
# note_x：nan
# ファイル：ZCH0133.wav 処理完了, 推定：126, 頻脈判定：[1], NN分散：0.126, 0.013
# note_x：nan
# ファイル：ZCH0134.wav 処理完了, 推定：118, 頻脈判定：[1], NN分散：0.022, 0.016
# note_x：nan
# ファイル：ZCH0138.wav 処理完了, 推定：126, 頻脈判定：[1], NN分散：0.077, 0.025
# note_x：nan
# ファイル：ZCH0140.wav 処理完了, 推定：158, 頻脈判定：[1], NN分散：0.066, 0.020
# note_x：nan
# ファイル：1005_20240318071618_3783.wav 処理完了, 推定：61, 頻脈判定：[0], NN分散：0.018, 0.036
# note_x：正常
# ファイル：1005_20240318114557_3800.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.033, 0.019
# note_x：正常
# ファイル：1005_20240503075153_9517.wav 処理完了, 推定：65, 頻脈判定：[0], NN分散：0.002, 0.038
# note_x：nan
# ファイル：1005_20240517181735_11606.wav 処理完了, 推定：71, 頻脈判定：[0], NN分散：0.022, 0.032
# note_x：nan
# ファイル：1005_20240708070747_19391.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.044, 0.060
# note_x：正常
# ファイル：3010_20240710080039_19813.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.076, 0.012
# note_x：正常
# ファイル：3010_20240904125929_28295.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.106, 0.028
# note_x：正常
# ファイル：3010_20240712080109_20199.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.047, 0.039
# note_x：正常
# ファイル：3010_20240826131009_27159.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.054, 0.034
# note_x：nan
# ファイル：4003_20240406180104_6088.wav 処理完了, 推定：75, 頻脈判定：[0], NN分散：0.000, 0.039
# note_x：正常
# ファイル：4003_20240515180033_11311.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.001, 0.042
# note_x：正常
# ファイル：4003_20240607080051_14482.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.045, 0.009
# note_x：正常
# ファイル：4003_20240701080629_18184.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.041, 0.007
# note_x：正常
# ファイル：4015_20240803180117_24045.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.079, 0.031
# note_x：nan
# ファイル：4018_20241008070336_32578.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.081, 0.022
# note_x：正常
# ファイル：ZCH0141.wav 処理完了, 推定：114, 頻脈判定：[1], NN分散：0.079, 0.029
# note_x：nan
# Skipping ZCH0151.wav due to low volume (vol_mean=2592.0)
# ファイル：ZCH0152.wav 処理完了, 推定：122, 頻脈判定：[1], NN分散：0.082, 0.000
# note_x：nan
# ファイル：ZCH0158.wav 処理完了, 推定：150, 頻脈判定：[1], NN分散：0.091, 0.020
# note_x：nan
# ファイル：ZCH0167.wav 処理完了, 推定：120, 頻脈判定：[1], NN分散：0.096, 0.019
# note_x：nan
# ファイル：ZCH0174.wav 処理完了, 推定：146, 頻脈判定：[1], NN分散：0.095, 0.009
# note_x：nan
# Skipping ZCH0183.wav due to low volume (vol_mean=1186.0)
# ファイル：ZCH0184.wav 処理完了, 推定：114, 頻脈判定：[1], NN分散：0.034, 0.022
# note_x：nan
# ファイル：ZCH0201.wav 処理完了, 推定：132, 頻脈判定：[1], NN分散：0.074, 0.009
# note_x：nan
# Skipping ZCH0226.wav due to low volume (vol_mean=2620.0)
# ファイル：ZCH0241.wav 処理完了, 推定：123, 頻脈判定：[1], NN分散：0.062, 0.027
# note_x：nan
# ファイル：ZCH0259.wav 処理完了, 推定：126, 頻脈判定：[1], NN分散：0.123, 0.000
# note_x：nan
# ファイル：ZCH0260.wav 処理完了, 推定：128, 頻脈判定：[1], NN分散：0.092, 0.006
# note_x：nan
# ファイル：ZCH0271.wav 処理完了, 推定：136, 頻脈判定：[1], NN分散：0.088, 0.024
# note_x：nan
# Skipping ZCH0284.wav due to low volume (vol_mean=2168.0)
# ファイル：ZCH0350.wav 処理完了, 推定：123, 頻脈判定：[1], NN分散：0.105, 0.082
# note_x：nan
# ファイル：1004_20240314191205_3443.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.100, 0.046
# note_x：AFから洞調律に戻ったのか。PACらしき音は混ざっているが、正常。
# ファイル：1004_20240504130625_9730.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.010, 0.017
# note_x：AFibだが、正常
# ファイル：1004_20240504185837_9802.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.079, 0.061
# note_x：AFibのせいでノイズありと判定されているが、これは正常。
# ファイル：1004_20240229133857_2023.wav 処理完了, 推定：134, 頻脈判定：[1], NN分散：0.048, 0.032
# note_x：AFib, 収縮期の雑音は小さめ。Ⅲ音なし。肺動脈駆出性クリックはほとんど聴取しない
# ファイル：1004_20240308130351_2811.wav 処理完了, 推定：71, 頻脈判定：[0], NN分散：0.068, 0.028
# note_x：AFib, 収縮期に音が割れているがⅢ音なし
# ファイル：4007_20240312153123_3224.wav 処理完了, 推定：77, 頻脈判定：[0], NN分散：0.066, 0.020
# note_x：AFib, S3なし。
# ファイル：4007_20240312153517_3226.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.036, 0.020
# note_x：AFib, S3なし。
# ファイル：4007_20240312154045_3229.wav 処理完了, 推定：63, 頻脈判定：[0], NN分散：0.051, 0.028
# note_x：AFib, S3なし。
# ファイル：4007_20240312154456_3231.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.044, 0.029
# note_x：AFib, S3なし。
# ファイル：4007_20240312154648_3232.wav 処理完了, 推定：71, 頻脈判定：[0], NN分散：0.056, 0.031
# note_x：AFib, S3なし。
# ファイル：4007_20240312160016_3237.wav 処理完了, 推定：69, 頻脈判定：[0], NN分散：0.103, 0.038
# note_x：AFibなのか。Ⅲ音なし。
# ファイル：4007_20240312160720_3241.wav 処理完了, 推定：77, 頻脈判定：[0], NN分散：0.038, 0.033
# note_x：AFib, S3なし
# ファイル：4007_20240312161137_3245.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.097, 0.036
# note_x：AFib, S3なし
# ファイル：4007_20240313073909_3289.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.037, 0.018
# note_x：AFib, S3なし
# ファイル：4007_20240313133151_3315.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.032, 0.030
# note_x：AFib, S3なし
# ファイル：4007_20240313180216_3333.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.040, 0.027
# note_x：AFib, S3なし
# ファイル：4007_20240313180645_3340.wav 処理完了, 推定：83, 頻脈判定：[0], NN分散：0.025, 0.019
# note_x：AFib, S3なし
# ファイル：4007_20240313180743_3341.wav 処理完了, 推定：63, 頻脈判定：[0], NN分散：0.105, 0.044
# note_x：AFib, 5秒あたりにS3のように聞こえる部分があるがおそらくこれはPVC
# Skipping 4007_20240314071039_3356.wav due to low volume (vol_mean=2681.0)
# ファイル：4007_20240314071155_3357.wav 処理完了, 推定：130, 頻脈判定：[1], NN分散：0.075, 0.042
# note_x：AFib, S3なし
# ファイル：1004_20240315123354_3497.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.078, 0.023
# note_x：AFibなのか不整脈になっている。Ⅲ音なし
# ファイル：1004_20240315190840_3546.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.156, 0.022
# note_x：AFibだがⅢ音なし
# ファイル：1004_20240315190931_3547.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.070, 0.034
# note_x：AFibだがⅢ音なし
# ファイル：1004_20240315191020_3548.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.148, 0.019
# note_x：AFibだがⅢ音なし
# ファイル：1004_20240315191112_3549.wav 処理完了, 推定：48, 頻脈判定：[0], NN分散：0.147, 0.019
# note_x：AFibだがⅢ音なし
# ファイル：1004_20240315191207_3550.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.069, 0.029
# note_x：AFibだがⅢ音なし
# ファイル：1004_20240315191323_3551.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.035, 0.048
# note_x：AFib, １音の分裂（肺動脈駆出性クリック）のような音がずっとしている。Ⅲ音なし。ただし頻脈なのでかなりしんどそう。呼び出してもいいのでは？
# ファイル：1004_20240315191416_3552.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.021, 0.029
# note_x：AFib, １音の分裂のような音がずっとしている。Ⅲ音なし。ただし頻脈なのでかなりしんどそう。呼び出してもいいのでは？
# ファイル：1004_20240315191509_3553.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.074, 0.024
# note_x：AFibだけどⅢ音なし。
# ファイル：1004_20240315191558_3554.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.039, 0.029
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240315191655_3555.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.070, 0.024
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240315191835_3556.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.060, 0.038
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240315191923_3557.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.054, 0.035
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240315192017_3558.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.097, 0.036
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240315192106_3559.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.121, 0.029
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240315192202_3560.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.072, 0.018
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240315192319_3561.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.114, 0.112
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240315192423_3562.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.070, 0.040
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240316090022_3592.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.106, 0.006
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240316090402_3596.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.047, 0.022
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240316131604_3625.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.070, 0.041
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240316131656_3626.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.092, 0.023
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240316133335_3644.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.060, 0.033
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240317085826_3703.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.101, 0.049
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240317123724_3719.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.057, 0.035
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240317191258_3764.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.033, 0.039
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240317191803_3770.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.061, 0.038
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240317191852_3771.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.189, 0.038
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240318124844_3810.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.071, 0.018
# note_x：おそらくAFibになっている。Ⅰ音の分裂が続いている。
# ファイル：1004_20240318124935_3812.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.070, 0.029
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240318125112_3815.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.055, 0.026
# note_x：AFibになっている。時々脈も早い。
# ファイル：1004_20240318125205_3816.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.054, 0.036
# note_x：AFib, Ⅲ音なし
# ファイル：1004_20240318125437_3820.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.042, 0.019
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240318125621_3824.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.090, 0.045
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240318135621_3890.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.090, 0.034
# note_x：AFibだけどⅢ音なし。
# ファイル：1004_20240318190423_3920.wav 処理完了, 推定：69, 頻脈判定：[0], NN分散：0.045, 0.044
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240319090917_3949.wav 処理完了, 推定：56, 頻脈判定：[0], NN分散：0.109, 0.059
# note_x：シグナル小さめ。AFibだけどⅢ音なし
# ファイル：1004_20240319122720_3965.wav 処理完了, 推定：55, 頻脈判定：[0], NN分散：0.040, 0.035
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240319123320_3973.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.116, 0.060
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240319192705_4039.wav 処理完了, 推定：75, 頻脈判定：[0], NN分散：0.066, 0.056
# note_x：AFibだけどⅢ音なし。
# ファイル：1004_20240320091915_4062.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.101, 0.034
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240320130117_4071.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.055, 0.033
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240320130216_4074.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.034, 0.032
# note_x：AFibだけどⅢ音なし
# ファイル：1004_20240320191438_4114.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.042, 0.018
# note_x：AFibだけどⅢ音なし。時々頻脈になっている。
# ファイル：1004_20240320191537_4115.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.063, 0.024
# note_x：AFibだけどⅢ音なし。時々頻脈になっている。
# ファイル：1004_20240320191729_4117.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.082, 0.042
# note_x：AFibだけどⅢ音なし。時々頻脈になっている。
# ファイル：1004_20240320191912_4119.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.060, 0.039
# note_x：AFibだけどⅢ音なし。時々頻脈になっている。
# ファイル：1004_20240320192003_4120.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.041, 0.039
# note_x：AFibだけどⅢ音なし。時々頻脈になっている。
# ファイル：1004_20240321085938_4145.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.051, 0.033
# note_x：AFibだけどⅢ音なし。時々頻脈になっている。
# ファイル：1004_20240321160731_4242.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.063, 0.034
# note_x：AFibだけどⅢ音なし。時々頻脈になっている。
# ファイル：1004_20240322091708_4302.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.047, 0.004
# note_x：AFib, 収縮期早期クリック音 (Ejection Sound) がずっとなっている。がⅢ音なし
# ファイル：1004_20240322091807_4303.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.062, 0.018
# note_x：AFib, 肺動脈駆出性クリック音がずっと続いている。S3ではない。
# ファイル：1004_20240325131628_4636.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.434, 0.230
# note_x：AFibで頻脈になっている。苦しそう。
# ファイル：1004_20240402185554_5639.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.035, 0.020
# note_x：AFib, S1の分裂あり, 収縮期雑音あり, 脈早い
# ファイル：1004_20240402185655_5640.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.117, 0.032
# note_x：AFib, S1の分裂あり, 収縮期雑音あり, 脈早い
# ファイル：1004_20240403084743_5671.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.051, 0.017
# note_x：AFib, S1の分裂あり, 収縮期雑音あり, 脈早い
# ファイル：1004_20240403084832_5672.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.036, 0.020
# note_x：AFib, S1の分裂あり, 収縮期雑音あり, 脈早い
# ファイル：1004_20240403084928_5673.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.047, 0.025
# note_x：AFib, S1の分裂あり, 収縮期雑音あり, 脈早い
# ファイル：1004_20240403085023_5674.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.065, 0.031
# note_x：AFib, S1の分裂あり, 脈早い
# ファイル：1004_20240403190256_5745.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.078, 0.030
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240403190347_5746.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.024, 0.035
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240403190437_5747.wav 処理完了, 推定：81, 頻脈判定：[0], NN分散：0.021, 0.017
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240404083616_5781.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.046, 0.022
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240404083710_5782.wav 処理完了, 推定：75, 頻脈判定：[0], NN分散：0.049, 0.021
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240404122346_5795.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.057, 0.028
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240404125151_5798.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.049, 0.031
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240404125242_5799.wav 処理完了, 推定：126, 頻脈判定：[1], NN分散：0.107, 0.028
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240404125331_5800.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.041, 0.019
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240404184322_5864.wav 処理完了, 推定：77, 頻脈判定：[0], NN分散：0.027, 0.024
# note_x：AFib, S1分裂あり, 脈早い
# ファイル：1004_20240404184411_5865.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.058, 0.026
# note_x：AFib, S1分裂あり, 脈早い
# ファイル：1004_20240404184501_5866.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.052, 0.020
# note_x：AFib, S1分裂あり, 脈早い
# ファイル：1004_20240404184548_5867.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.082, 0.027
# note_x：AFib,  S1分裂あり, 脈早い
# ファイル：1004_20240405123440_5924.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.047, 0.045
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240405123623_5926.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.114, 0.053
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240405130726_5938.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.041, 0.032
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240405130830_5940.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.068, 0.033
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240405130931_5942.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.071, 0.034
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240405131042_5945.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.075, 0.037
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240405131133_5946.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.127, 0.035
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240405190224_5982.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.154, 0.019
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240406085738_6026.wav 処理完了, 推定：73, 頻脈判定：[0], NN分散：0.060, 0.029
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240406085836_6027.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.036, 0.030
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240406123807_6042.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.099, 0.016
# note_x：AFib, S1分裂あり, 脈早い
# ファイル：1004_20240406123902_6043.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.059, 0.021
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240406124054_6045.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.036, 0.020
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240406185507_6108.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.020, 0.032
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240406185604_6109.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.053, 0.020
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240406185701_6110.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.043, 0.037
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240406185749_6111.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.042, 0.015
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240406185838_6112.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.051, 0.021
# note_x：AFib, S1分裂あり, 脈早い
# ファイル：1004_20240407124012_6178.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.066, 0.019
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240407124115_6179.wav 処理完了, 推定：56, 頻脈判定：[0], NN分散：0.044, 0.016
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240407124205_6180.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.048, 0.028
# note_x：AFib, S1分裂あり, 脈早い
# ファイル：1004_20240407124300_6181.wav 処理完了, 推定：75, 頻脈判定：[0], NN分散：0.062, 0.018
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240407124401_6182.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.062, 0.046
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240407185158_6239.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.060, 0.027
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240407185257_6240.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.039, 0.014
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240407185351_6241.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.102, 0.032
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240408090058_6292.wav 処理完了, 推定：56, 頻脈判定：[0], NN分散：0.039, 0.038
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240408090152_6293.wav 処理完了, 推定：78, 頻脈判定：[0], NN分散：0.060, 0.032
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240408130630_6327.wav 処理完了, 推定：81, 頻脈判定：[0], NN分散：0.044, 0.027
# note_x：AFib, S1分裂あり, 脈早い
# ファイル：1004_20240408130726_6330.wav 処理完了, 推定：71, 頻脈判定：[0], NN分散：0.088, 0.009
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240408130821_6332.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.102, 0.015
# note_x：AFib, 収縮期雑音あり, S1分裂あり, 脈早い
# ファイル：1004_20240408130916_6334.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.048, 0.017
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240408131012_6335.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.060, 0.025
# note_x：AFib, S1が分裂している, 収縮期雑音あり、脈早い
# ファイル：1004_20240408190900_6381.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.096, 0.017
# note_x：AFib, S1が分裂している, 脈早い
# ファイル：1004_20240408190955_6382.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.075, 0.027
# note_x：AFib, S1が分裂している, 脈早い
# ファイル：1004_20240408191138_6384.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.081, 0.025
# note_x：AFib, S1が分裂している, 脈早い
# ファイル：1004_20240408191230_6385.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.110, 0.038
# note_x：特に前半にⅢ音あり. AFib
# ファイル：1004_20240409084051_6420.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.091, 0.027
# note_x：AFib, S1が割れている、収縮期雑音あり, 脈早い
# ファイル：1004_20240409084806_6421.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.122, 0.032
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240409085012_6423.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.074, 0.013
# note_x：AFib, S1が割れている、収縮期雑音あり, 脈早い
# ファイル：1004_20240409085111_6424.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.100, 0.024
# note_x：AFib, S1が割れている、収縮期雑音あり, 脈早い
# ファイル：1004_20240409122819_6434.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.069, 0.021
# note_x：AFib, S1が割れている、収縮期雑音あり, 脈早い
# ファイル：1004_20240409122918_6436.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.079, 0.023
# note_x：AFib, S1が割れている、収縮期雑音あり, 脈早い
# ファイル：1004_20240409123111_6439.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.102, 0.029
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240409123207_6441.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.060, 0.045
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240409185615_6486.wav 処理完了, 推定：75, 頻脈判定：[0], NN分散：0.062, 0.021
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240409185822_6488.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.083, 0.026
# note_x：AFib, 収縮期雑音, 脈早い
# ファイル：1004_20240409185915_6489.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.144, 0.052
# note_x：AFib, 収縮期雑音, 脈早い
# ファイル：1004_20240409190016_6494.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.063, 0.031
# note_x：AFib, 収縮期雑音, 脈早い
# ファイル：1004_20240409194708_6496.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.038, 0.021
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240409195033_6499.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.040, 0.025
# note_x：AFib, 収縮期雑音, 脈早い
# ファイル：1004_20240409195220_6500.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.044, 0.031
# note_x：AFib,  収縮期雑音, 脈早い
# ファイル：1004_20240409195329_6501.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.158, 0.020
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240409195529_6502.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.152, 0.021
# note_x：AFib, S1が割れている, 収縮期雑音
# ファイル：1004_20240409195714_6503.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.132, 0.036
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240409195805_6504.wav 処理完了, 推定：69, 頻脈判定：[0], NN分散：0.068, 0.027
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240410090150_6537.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.058, 0.044
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い。後半3秒くらいにⅢ音らしき音あり。4割ルール満たさないためⅢ音なしとする。
# ファイル：1004_20240410090240_6538.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.075, 0.055
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240410122422_6550.wav 処理完了, 推定：45, 頻脈判定：[0], NN分散：0.150, 0.034
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240410122814_6554.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.097, 0.021
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240410141137_6584.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.057, 0.022
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い。ノイズ多め
# ファイル：1004_20240410191754_6624.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.048, 0.021
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240410191853_6625.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.049, 0.032
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240410191942_6626.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.077, 0.029
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240410192044_6628.wav 処理完了, 推定：73, 頻脈判定：[0], NN分散：0.057, 0.041
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240411085727_6666.wav 処理完了, 推定：83, 頻脈判定：[0], NN分散：0.059, 0.020
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240411085906_6668.wav 処理完了, 推定：69, 頻脈判定：[0], NN分散：0.078, 0.051
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240411085959_6669.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.146, 0.038
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240411125022_6693.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.041, 0.032
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240411125123_6696.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.078, 0.043
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240411125213_6698.wav 処理完了, 推定：75, 頻脈判定：[0], NN分散：0.067, 0.026
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240411125303_6700.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.057, 0.023
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240411185606_6753.wav 処理完了, 推定：123, 頻脈判定：[1], NN分散：0.066, 0.020
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240411185702_6754.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.070, 0.027
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240411185751_6755.wav 処理完了, 推定：71, 頻脈判定：[0], NN分散：0.173, 0.025
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240411185839_6756.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.077, 0.022
# note_x：AFib, S1が割れている,  脈早い
# ファイル：1004_20240411185926_6757.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.079, 0.040
# note_x：AFib, 収縮期雑音, 脈早い
# ファイル：1004_20240412090753_6805.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.066, 0.017
# note_x：AFib, S1が割れている, 収縮期雑音, 脈早い
# ファイル：1004_20240412090902_6806.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.082, 0.025
# note_x：AFib, 収縮期雑音, 脈早い
# ファイル：1004_20240412091047_6808.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.083, 0.024
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240412091137_6809.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.075, 0.014
# note_x：AFib, 収縮期雑音, 脈早い
# ファイル：1004_20240412124918_6826.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.068, 0.025
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240412125016_6827.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.058, 0.024
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240412125104_6828.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.047, 0.018
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240412125151_6829.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.115, 0.028
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240412185635_6892.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.092, 0.031
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240412185818_6893.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.048, 0.037
# note_x：AFib, S1が割れている
# ファイル：1004_20240412185907_6894.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.100, 0.050
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240412190006_6895.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.048, 0.016
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240413085726_6931.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.125, 0.023
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240413085830_6932.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.112, 0.057
# note_x：AFib, S1が割れている
# ファイル：1004_20240413085936_6934.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.181, 0.057
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240413125040_6947.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.051, 0.034
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240413125237_6949.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.054, 0.031
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240413184247_7012.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.070, 0.061
# note_x：AFib, 収縮期雑音あり, 脈早い
# ファイル：1004_20240414085802_7048.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.081, 0.036
# note_x：AFib, S1が割れている, 収縮期雑音あり、脈早い
# ファイル：1004_20240414085905_7049.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.090, 0.028
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240414125039_7071.wav 処理完了, 推定：69, 頻脈判定：[0], NN分散：0.062, 0.020
# note_x：AFib, 収縮期雑音,  脈早い
# ファイル：1004_20240414125219_7073.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.063, 0.021
# note_x：AFib, S1が割れている, 収縮期雑音あり、脈早い
# ファイル：1004_20240414184636_7126.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.082, 0.033
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240414184733_7127.wav 処理完了, 推定：78, 頻脈判定：[0], NN分散：0.077, 0.017
# note_x：AFib, S1が割れている, 脈早い
# ファイル：4007_20240415075330_7148.wav 処理完了, 推定：67, 頻脈判定：[0], NN分散：0.038, 0.029
# note_x：AFib
# ファイル：1004_20240415085450_7159.wav 処理完了, 推定：128, 頻脈判定：[1], NN分散：0.091, 0.016
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240415085549_7160.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.070, 0.041
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240415085637_7161.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.047, 0.037
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240415085728_7162.wav 処理完了, 推定：67, 頻脈判定：[0], NN分散：0.144, 0.043
# note_x：AFib, 収縮期雑音, 脈早い
# ファイル：4007_20240415123731_7183.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.081, 0.047
# note_x：AFib
# ファイル：1004_20240415124310_7187.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.111, 0.062
# note_x：AFib, S1が割れている
# ファイル：4007_20240415180321_7221.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.057, 0.040
# note_x：AFib
# ファイル：1004_20240415194103_7239.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.081, 0.035
# note_x：AFib, S1が割れている, 収縮期雑音あり、脈早い
# ファイル：1004_20240415194202_7240.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.072, 0.050
# note_x：AFib, S1が割れている
# ファイル：4007_20240416075039_7252.wav 処理完了, 推定：188, 頻脈判定：[1], NN分散：0.065, 0.019
# note_x：AFib
# ファイル：1004_20240416085351_7269.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.038, 0.022
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240416085451_7270.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.048, 0.017
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240416085539_7271.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.039, 0.053
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240416085630_7272.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.034, 0.036
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240416085720_7273.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.072, 0.050
# note_x：AFib, S1が割れている, 脈早い
# ファイル：1004_20240416123328_7292.wav 処理完了, 推定：63, 頻脈判定：[0], NN分散：0.067, 0.048
# note_x：AFib, S1が割れている
# ファイル：1004_20240416123421_7293.wav 処理完了, 推定：61, 頻脈判定：[0], NN分散：0.091, 0.057
# note_x：AFib, S1が割れている, 少し脈が速くなっている
# ファイル：1004_20240416123517_7294.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.076, 0.022
# note_x：AFib, S1が割れている
# ファイル：1004_20240416123657_7296.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.042, 0.027
# note_x：AFib, 収縮期雑音あり, I音の分裂目立つ
# ファイル：1004_20240416131756_7315.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.128, 0.024
# note_x：AFib, 収縮期雑音あり, I音の分裂目立つ
# ファイル：1004_20240416131847_7316.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.076, 0.017
# note_x：AFib, 収縮期雑音あり, I音の分裂目立つ
# ファイル：1004_20240416131938_7318.wav 処理完了, 推定：136, 頻脈判定：[1], NN分散：0.065, 0.020
# note_x：AFib, 収縮期雑音あり, I音の分裂目立つ
# ファイル：1004_20240416132029_7320.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.088, 0.037
# note_x：AFib, 収縮期雑音あり
# ファイル：4007_20240416132233_7323.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.071, 0.047
# note_x：AFib
# ファイル：4007_20240416182019_7353.wav 処理完了, 推定：73, 頻脈判定：[0], NN分散：0.050, 0.025
# note_x：AFib
# ファイル：1004_20240416191105_7358.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.044, 0.019
# note_x：AFib, 収縮期雑音あり, I音の分裂目立つ
# ファイル：1004_20240416191200_7359.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.036, 0.019
# note_x：AFib, 収縮期雑音あり, I音の分裂目立つ
# ファイル：1004_20240416191247_7360.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.056, 0.026
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240416191340_7361.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.048, 0.025
# note_x：AFib, 収縮期雑音あり, I音の分裂目立つ
# ファイル：1004_20240416191428_7362.wav 処理完了, 推定：59, 頻脈判定：[0], NN分散：0.136, 0.051
# note_x：AFib, 収縮期雑音あり
# ファイル：4007_20240417082631_7394.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.061, 0.028
# note_x：AFib
# ファイル：1004_20240417085620_7396.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.077, 0.037
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240417085721_7397.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.114, 0.047
# note_x：AFib, 収縮期雑音あり, I音の分裂目立つ
# ファイル：1004_20240417085815_7398.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.133, 0.042
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240417085905_7399.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.115, 0.051
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240417085953_7400.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.231, 0.029
# note_x：AFib, 収縮期雑音あり, 頻脈あり
# ファイル：1004_20240417125432_7411.wav 処理完了, 推定：85, 頻脈判定：[0], NN分散：0.041, 0.026
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240417125523_7412.wav 処理完了, 推定：140, 頻脈判定：[1], NN分散：0.296, 0.173
# note_x：AFib, 収縮期雑音あり
# ファイル：4007_20240417132026_7428.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.032, 0.038
# note_x：AFib
# ファイル：1004_20240417190510_7455.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.046, 0.033
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240417190608_7456.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.283, 0.053
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240417190659_7457.wav 処理完了, 推定：132, 頻脈判定：[1], NN分散：0.056, 0.043
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240417190753_7459.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.031, 0.034
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240417190851_7461.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.116, 0.091
# note_x：AFib, 収縮期雑音あり
# ファイル：4007_20240417191226_7466.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.066, 0.048
# note_x：AFib
# ファイル：4007_20240418081818_7489.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.054, 0.019
# note_x：AFib
# ファイル：1004_20240418085900_7497.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.050, 0.027
# note_x：AFib, I音の分裂あり
# ファイル：1004_20240418085952_7498.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.039, 0.031
# note_x：AFib, I音の分裂あり
# ファイル：1004_20240418090053_7499.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.056, 0.036
# note_x：AFib, 頻脈
# ファイル：1004_20240418124908_7511.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.044, 0.045
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240418124959_7512.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.035, 0.026
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240418125050_7513.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.023, 0.032
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240418125142_7514.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.083, 0.048
# note_x：AFib, 収縮期雑音あり
# ファイル：1004_20240418125233_7515.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.064, 0.030
# note_x：AFib, 収縮期雑音あり
# ファイル：4007_20240418135051_7533.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.043, 0.045
# note_x：AFib
# ファイル：4007_20240418190410_7568.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.100, 0.037
# note_x：AFib
# ファイル：1004_20240418191044_7569.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.074, 0.028
# note_x：AFib, 収縮期雑音あり
# ...
# note_x：nan
# ファイル：4007_20240701163952_18250.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.038, 0.045
# note_x：nan
# ファイル：4007_20240702074032_18312.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.008, 0.021
# note_x：nan
# ファイル：4007_20240702135030_18393.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.040, 0.035
# note_x：nan
# ファイル：4007_20240702135124_18394.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.073, 0.036
# note_x：nan
# ファイル：4007_20240702135345_18396.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.040, 0.012
# note_x：nan
# ファイル：4007_20240702190225_18445.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.042, 0.028
# note_x：nan
# ファイル：4007_20240702190344_18447.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.035, 0.013
# note_x：nan
# ファイル：4007_20240702190434_18448.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.060, 0.026
# note_x：nan
# ファイル：4007_20240703080315_18496.wav 処理完了, 推定：63, 頻脈判定：[0], NN分散：0.084, 0.025
# note_x：nan
# ファイル：4007_20240703131042_18549.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.054, 0.018
# note_x：nan
# ファイル：4007_20240703175955_18593.wav 処理完了, 推定：81, 頻脈判定：[0], NN分散：0.051, 0.015
# note_x：nan
# ファイル：4007_20240703180107_18596.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.048, 0.017
# note_x：nan
# ファイル：4007_20240704075846_18661.wav 処理完了, 推定：56, 頻脈判定：[0], NN分散：0.047, 0.021
# note_x：nan
# ファイル：4007_20240704151824_18747.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.062, 0.030
# note_x：nan
# ファイル：4007_20240704183334_18794.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.065, 0.038
# note_x：nan
# ファイル：4007_20240704183429_18795.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.037, 0.034
# note_x：nan
# ファイル：4007_20240705075544_18846.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.086, 0.063
# note_x：nan
# ファイル：4007_20240705133027_18924.wav 処理完了, 推定：87, 頻脈判定：[0], NN分散：0.041, 0.019
# note_x：nan
# ファイル：4007_20240705143504_18933.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.119, 0.043
# note_x：nan
# ファイル：4007_20240705203029_18998.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.096, 0.018
# note_x：nan
# ファイル：4007_20240706082207_19063.wav 処理完了, 推定：86, 頻脈判定：[0], NN分散：0.025, 0.010
# note_x：nan
# ファイル：4007_20240706145655_19138.wav 処理完了, 推定：123, 頻脈判定：[1], NN分散：0.050, 0.042
# note_x：nan
# ファイル：4007_20240706145834_19140.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.082, 0.020
# note_x：nan
# ファイル：4007_20240706150423_19149.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.039, 0.021
# note_x：nan
# ファイル：4007_20240706180350_19183.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.051, 0.043
# note_x：nan
# ファイル：4007_20240706180457_19186.wav 処理完了, 推定：69, 頻脈判定：[0], NN分散：0.074, 0.051
# note_x：nan
# ファイル：4007_20240707082655_19249.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.109, 0.035
# note_x：nan
# ファイル：4007_20240707131327_19316.wav 処理完了, 推定：82, 頻脈判定：[0], NN分散：0.080, 0.031
# note_x：nan
# ファイル：4007_20240707173632_19336.wav 処理完了, 推定：69, 頻脈判定：[0], NN分散：0.088, 0.031
# note_x：nan
# ファイル：4007_20240707180108_19355.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.087, 0.020
# note_x：nan
# ファイル：4007_20240707180205_19357.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.018, 0.016
# note_x：nan
# ファイル：4007_20240708081652_19418.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.056, 0.034
# note_x：nan
# ファイル：4007_20240708081748_19419.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.097, 0.026
# note_x：nan
# ファイル：3001_20240708130817_19489.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.062, 0.058
# note_x：徐脈かつ二段脈
# ファイル：3001_20240708131113_19492.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.065, 0.078
# note_x：徐脈かつ二段脈
# ファイル：4007_20240708133324_19497.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.168, 0.025
# note_x：nan
# ファイル：4007_20240708133421_19498.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.055, 0.045
# note_x：nan
# ファイル：4007_20240708133601_19499.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.105, 0.048
# note_x：nan
# ファイル：4007_20240708133700_19500.wav 処理完了, 推定：63, 頻脈判定：[0], NN分散：0.095, 0.092
# note_x：nan
# ファイル：3001_20240708184407_19557.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.120, 0.081
# note_x：徐脈かつ二段脈
# ファイル：4007_20240708214016_19564.wav 処理完了, 推定：75, 頻脈判定：[0], NN分散：0.066, 0.024
# note_x：nan
# ファイル：4007_20240708214119_19565.wav 処理完了, 推定：83, 頻脈判定：[0], NN分散：0.081, 0.040
# note_x：nan
# ファイル：4007_20240708214220_19566.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.052, 0.020
# note_x：nan
# ファイル：4007_20240708214311_19567.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.057, 0.015
# note_x：nan
# ファイル：3001_20240709064956_19581.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.111, 0.053
# note_x：徐脈かつ二段脈
# ファイル：4007_20240709074601_19595.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.015, 0.017
# note_x：nan
# ファイル：4007_20240709130239_19679.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.037, 0.039
# note_x：nan
# ファイル：4007_20240709130335_19681.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.087, 0.029
# note_x：nan
# ファイル：4007_20240709130537_19687.wav 処理完了, 推定：77, 頻脈判定：[0], NN分散：0.074, 0.018
# note_x：nan
# ファイル：3001_20240709130800_19689.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.120, 0.147
# note_x：徐脈かつ二段脈
# ファイル：3001_20240709181633_19756.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.106, 0.060
# note_x：徐脈かつ二段脈
# ファイル：4007_20240709205253_19771.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.052, 0.023
# note_x：nan
# ファイル：3001_20240710065153_19785.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.096, 0.047
# note_x：徐脈かつ二段脈
# ファイル：4007_20240710075631_19807.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.062, 0.025
# note_x：nan
# ファイル：4007_20240710075725_19808.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.123, 0.053
# note_x：nan
# ファイル：3001_20240710130924_19902.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.053, 0.048
# note_x：徐脈かつ二段脈
# ファイル：3001_20240710180124_19949.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.119, 0.075
# note_x：徐脈かつ二段脈
# ファイル：3001_20240711071534_20000.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.125, 0.043
# note_x：徐脈かつ二段脈
# ファイル：2001_20240711073836_20015.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.067, 0.035
# note_x：nan
# ファイル：4007_20240711073958_20016.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.020, 0.005
# note_x：nan
# ファイル：3001_20240711124521_20063.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.132, 0.058
# note_x：徐脈かつ二段脈
# ファイル：4007_20240711130409_20095.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.041, 0.020
# note_x：nan
# ファイル：4007_20240711130501_20097.wav 処理完了, 推定：78, 頻脈判定：[0], NN分散：0.041, 0.023
# note_x：nan
# ファイル：4007_20240712075459_20191.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.045, 0.027
# note_x：nan
# ファイル：4007_20240712133222_20282.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.051, 0.015
# note_x：nan
# ファイル：4007_20240712133309_20283.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.072, 0.045
# note_x：nan
# ファイル：4007_20240712172927_20303.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.057, 0.013
# note_x：nan
# ファイル：4007_20240712173023_20304.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.045, 0.022
# note_x：nan
# ファイル：4007_20240712173128_20305.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.020, 0.017
# note_x：nan
# ファイル：4007_20240713081120_20392.wav 処理完了, 推定：71, 頻脈判定：[0], NN分散：0.059, 0.024
# note_x：nan
# ファイル：4007_20240713135215_20466.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.044, 0.025
# note_x：nan
# ファイル：4007_20240713135529_20469.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.073, 0.050
# note_x：nan
# ファイル：4007_20240713183250_20515.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.083, 0.044
# note_x：nan
# ファイル：4007_20240713183457_20517.wav 処理完了, 推定：75, 頻脈判定：[0], NN分散：0.065, 0.009
# note_x：nan
# ファイル：4007_20240714074905_20556.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.041, 0.023
# note_x：nan
# ファイル：4007_20240714075007_20557.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.072, 0.026
# note_x：nan
# ファイル：4007_20240714075255_20561.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.038, 0.009
# note_x：nan
# ファイル：4007_20240714161824_20658.wav 処理完了, 推定：81, 頻脈判定：[0], NN分散：0.038, 0.023
# note_x：nan
# ファイル：4007_20240714161931_20660.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.060, 0.023
# note_x：nan
# ファイル：4007_20240714162025_20661.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.068, 0.024
# note_x：nan
# ファイル：4007_20240715092429_20778.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.055, 0.021
# note_x：nan
# ファイル：4007_20240715092529_20780.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.019, 0.014
# note_x：nan
# ファイル：4007_20240715092635_20781.wav 処理完了, 推定：184, 頻脈判定：[1], NN分散：0.054, 0.020
# note_x：nan
# ファイル：4007_20240715220208_20891.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.030, 0.022
# note_x：nan
# ファイル：4007_20240716080110_20921.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.076, 0.031
# note_x：nan
# ファイル：4007_20240716083132_20932.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.066, 0.009
# note_x：nan
# ファイル：4007_20240716152717_21000.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.049, 0.015
# note_x：nan
# ファイル：4007_20240717125714_21161.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.098, 0.032
# note_x：nan
# ファイル：4007_20240717175054_21208.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.050, 0.025
# note_x：nan
# ファイル：3009_20240229072707_1993.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.010, 0.027
# note_x：APCらしき不整脈があるが、基本的に正常な心音。
# ファイル：1011_20240724210121_22419.wav 処理完了, 推定：70, 頻脈判定：[0], NN分散：0.096, 0.049
# note_x：PVC4拍くらいある
# ファイル：1011_20240725085654_22476.wav 処理完了, 推定：74, 頻脈判定：[0], NN分散：0.069, 0.072
# note_x：PVC２拍
# ファイル：1011_20240725130200_22517.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.024, 0.041
# note_x：PVC散発
# ファイル：5001_20240725194208_22596.wav 処理完了, 推定：73, 頻脈判定：[0], NN分散：0.058, 0.015
# note_x：PACか何かの不整脈があり分かりにくいが、PAC以外の部分ではⅢ音あり
# ファイル：1011_20240725205159_22599.wav 処理完了, 推定：65, 頻脈判定：[0], NN分散：0.066, 0.056
# note_x：PVC散発
# ファイル：2001_20240726080240_22633.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.027, 0.050
# note_x：nan
# Skipping 2001_20240726122027_22671.wav due to low volume (vol_mean=2375.0)
# ファイル：2001_20240726122124_22672.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.039, 0.037
# note_x：nan
# ファイル：2001_20240726122225_22673.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.088, 0.087
# note_x：nan
# ファイル：3011_20240428122111_8832.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.001, 0.044
# note_x：10秒あたりに1回だけPACらしき音が混ざっているが、基本正常。
# ファイル：3011_20240430133003_9161.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.078, 0.037
# note_x：おそらく補充調律としてPVCが3回出現している。基本正常。
# ファイル：4007_20240803190340_24070.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.067, 0.030
# note_x：nan
# ファイル：4002_20240217142849_1407.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.125, 0.096
# note_x：正常
# ファイル：1012_20240828080107_27363.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.033, 0.035
# note_x：nan
# ファイル：1012_20240831180059_27829.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.096, 0.036
# note_x：nan
# ファイル：1012_20240901082001_27895.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.039, 0.019
# note_x：nan
# ファイル：4007_20240905084523_28383.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.087, 0.026
# note_x：nan
# ファイル：4007_20240905084856_28388.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.092, 0.030
# note_x：nan
# ファイル：4007_20240905133116_28441.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.039, 0.024
# note_x：nan
# ファイル：4007_20240905133222_28442.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.043, 0.036
# note_x：nan
# ファイル：4007_20240905195119_28502.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.034, 0.023
# note_x：nan
# ファイル：4007_20240906082112_28542.wav 処理完了, 推定：77, 頻脈判定：[0], NN分散：0.047, 0.023
# note_x：nan
# ファイル：4007_20240906082224_28543.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.021, 0.027
# note_x：nan
# ファイル：4007_20240908144306_28943.wav 処理完了, 推定：67, 頻脈判定：[0], NN分散：0.140, 0.101
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240908144403_28944.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.067, 0.049
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240908144450_28945.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.035, 0.076
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240908144618_28946.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.044, 0.039
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240908233113_29002.wav 処理完了, 推定：122, 頻脈判定：[1], NN分散：0.027, 0.027
# note_x：正常。PACらしき不整脈が数拍あり。ぎゅむぎゅむ鳴ってる
# ファイル：4007_20240908233217_29003.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.162, 0.030
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240909102118_29050.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.123, 0.021
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240909201417_29146.wav 処理完了, 推定：56, 頻脈判定：[0], NN分散：0.080, 0.033
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910073730_29179.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.067, 0.026
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910073835_29180.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.074, 0.032
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240908131951_28929.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.035, 0.039
# note_x：nan
# ファイル：4007_20240910073933_29181.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.054, 0.030
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240908144200_28942.wav 処理完了, 推定：78, 頻脈判定：[0], NN分散：0.041, 0.046
# note_x：nan
# ファイル：4007_20240910074026_29182.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.058, 0.037
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910074115_29183.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.068, 0.016
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910080233_29190.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.063, 0.026
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910080324_29191.wav 処理完了, 推定：78, 頻脈判定：[0], NN分散：0.036, 0.029
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910080432_29193.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.046, 0.039
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910080539_29196.wav 処理完了, 推定：71, 頻脈判定：[0], NN分散：0.067, 0.025
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910080632_29199.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.051, 0.029
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910132718_29248.wav 処理完了, 推定：62, 頻脈判定：[0], NN分散：0.106, 0.044
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910132804_29249.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.041, 0.054
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910132856_29250.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.047, 0.050
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910132945_29251.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.036, 0.059
# note_x：正常。PACらしき不整脈が数拍あり。
# ファイル：4007_20240910132619_29246.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.043, 0.027
# note_x：nan
# ファイル：2001_20241009081553_32702.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.076, 0.027
# note_x：nan
# ファイル：2001_20241010082418_32834.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.047, 0.039
# note_x：nan
# ファイル：2001_20241010180048_32891.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.057, 0.027
# note_x：nan
# ファイル：2001_20241015071538_33388.wav 処理完了, 推定：79, 頻脈判定：[0], NN分散：0.040, 0.047
# note_x：nan
# ファイル：2001_20241015124128_33426.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.050, 0.023
# note_x：nan
# ファイル：5001_20240620193033_16547.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.064, 0.040
# note_x：3拍くらいPACらしき不整脈あり。基本的に正常
# ファイル：1012_20241104175652_35486.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.068, 0.028
# note_x：nan
# ファイル：1011_20241121125557_36909.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.118, 0.110
# note_x：PVCらしきもの散発
# ファイル：1011_20241121204556_36945.wav 処理完了, 推定：60, 頻脈判定：[0], NN分散：0.126, 0.112
# note_x：PVC散発
# ファイル：1012_20241205172927_37767.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.020, 0.012
# note_x：PACの後からⅢ音がはっきりと聞こえる。
# ファイル：1012_20241206131145_37794.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.055, 0.020
# note_x：4割強でⅢ音あり。
# ファイル：1012_20241207091153_37843.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.055, 0.030
# note_x：PAC多めだが、Ⅲ音あり
# ファイル：1012_20241208095216_37892.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.051, 0.017
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241208125150_37903.wav 処理完了, 推定：86, 頻脈判定：[0], NN分散：0.078, 0.026
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241209090502_37947.wav 処理完了, 推定：164, 頻脈判定：[1], NN分散：0.049, 0.013
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241210093757_38008.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.044, 0.007
# note_x：ほぼ全てにⅢ音あり。
# ファイル：5001_20240729064743_24748.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.040, 0.030
# note_x：PACらしきものが多いが、正常な心拍の後はほぼ全てⅢ音が聞こえる
# ファイル：1012_20241210141555_38029.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.051, 0.024
# note_x：ほぼ全てにⅢ音あり。かなり大きめのⅢ音が鳴っているため、ノイズと判定されて解析失敗になっているのかもしれない。
# ファイル：1012_20241210141653_38030.wav 処理完了, 推定：72, 頻脈判定：[0], NN分散：0.061, 0.047
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241210141750_38031.wav 処理完了, 推定：88, 頻脈判定：[0], NN分散：0.025, 0.021
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241210193349_38044.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.024, 0.021
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241211090830_38064.wav 処理完了, 推定：92, 頻脈判定：[0], NN分散：0.070, 0.005
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241211131112_38073.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.065, 0.034
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241211175602_38092.wav 処理完了, 推定：91, 頻脈判定：[0], NN分散：0.080, 0.031
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241212082929_38122.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.043, 0.007
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1011_20241212130439_38144.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.064, 0.113
# note_x：二段脈
# ファイル：1012_20241212180039_38160.wav 処理完了, 推定：84, 頻脈判定：[0], NN分散：0.055, 0.023
# note_x：中盤以降にはっきりとⅢ音あり。
# ファイル：1012_20241213093304_38184.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.061, 0.013
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241213130112_38193.wav 処理完了, 推定：80, 頻脈判定：[0], NN分散：0.067, 0.015
# note_x：ほぼ全てにⅢ音あり。
# ファイル：1012_20241213130220_38196.wav 処理完了, 推定：68, 頻脈判定：[0], NN分散：0.065, 0.034
# note_x：PAC多いが、ほぼ全てにⅢ音あり。
# ファイル：1012_20241214135059_38242.wav 処理完了, 推定：86, 頻脈判定：[0], NN分散：0.153, 0.053
# note_x：シグナル弱めだが、他のソフトで増幅すると明らかにⅢ音あり。
# ファイル：1012_20241214183031_38259.wav 処理完了, 推定：128, 頻脈判定：[1], NN分散：0.057, 0.035
# note_x：シグナル弱めだが、Ⅲ音あり。他のソフトで音を増幅させるとよくわかる。
# ファイル：1012_20241214183128_38260.wav 処理完了, 推定：123, 頻脈判定：[1], NN分散：0.011, 0.036
# note_x：PACなのか不明だが、Ⅲ音あり
# ファイル：1012_20241218095725_38439.wav 処理完了, 推定：64, 頻脈判定：[0], NN分散：0.077, 0.040
# note_x：PACらしきものが混ざるが、Ⅲ音あり。
# ファイル：1012_20241218130147_38454.wav 処理完了, 推定：76, 頻脈判定：[0], NN分散：0.012, 0.024
# note_x：PACらしきものが混ざるが、Ⅲ音あり。
# 結果を保存しました。
